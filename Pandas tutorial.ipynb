# %% [markdown]
# # iMPORT PANDAS BEFORE GETTING STARTED

# %%
#Import packages pandas packages
import pandas as pd

# %% [markdown]
# # creating dataframe from dictionary sequence

# %%
UR_Web_Visit = {
    'Day':[1,2,3,4,5,6],
    'Visitors':[2000,1500,5000,2000,900,750],
    'Bounce Rate':[30,30,28,21,15,38]
}

#convergt dictionary into pandas dataframe and store into df variable
df = pd.DataFrame(UR_Web_Visit)

#print df (df is a dataframe variable)
df
# Out:
#    Day  Visitors  Bounce Rate
# 0    1      2000           30
# 1    2      1500           30
# 2    3      5000           28
# 3    4      2000           21
# 4    5       900           15
# 5    6       750           38

# %%
# Reading csv external file using pandas
product_df=pd.read_csv('datasets/product.csv')
#printing product_df data frame
product_df
# Out:
#    Product_ID Product_Name     Category  Price Seller_City
# 0         101        Watch      Fashion    299       Delhi
# 1         102          Bag      Fashion   1350      Mumbai
# 2         103        Shoes      Fashion   2999     Chennai
# 3         104   Smartphone  Electronics  14999     Klokata
# 4         105        Books        Study    145       Delhi
# 5         106          Oil      Grocery    110     Chennai
# 6         107       Laptop  Electronics  79999   Bengalore

# %% [markdown]
# # Slicing first two rows

# %%
# To print first-two element we use head function and pass 2 as an argument
#If you want to print more/less rows, you can increase/decrease argument value
# If you dont provide an argument in head() function. It prints first-five rows by default
df.head(2)
# Out:
#    Day  Visitors  Bounce Rate
# 0    1      2000           30
# 1    2      1500           30

# %% [markdown]
# # Slicing last two rows

# %%
# To print first-two element we use tail function and pass 2 as an argument
#If you want to print more/less rows, you can increase/decrease argument value
# If you dont provide an argument in tail() function. It prints last-five rows by default
df.tail(2)
# Out:
#    Day  Visitors  Bounce Rate
# 4    5       900           15
# 5    6       750           38

# %%
df.sample(3)
# Out:
#    Day  Visitors  Bounce Rate
# 1    2      1500           30
# 5    6       750           38
# 2    3      5000           28

# %%
import statistics as sts
usr=df.Visitors
print(usr)
m=sts.median(usr)
print(m)
# Out:
# 0    2000
# 1    1500
# 2    5000
# 3    2000
# 4     900
# 5     750
# Name: Visitors, dtype: int64
# 1750.0

# %% [markdown]
# # merge dataframe

# %%
# Reading csv external file using pandas
product_df=pd.read_csv('datasets/product.csv')
#printing product_df data frame
product_df
# Out:
#    Product_ID Product_Name     Category  Price Seller_City
# 0         101        Watch      Fashion    299       Delhi
# 1         102          Bag      Fashion   1350      Mumbai
# 2         103        Shoes      Fashion   2999     Chennai
# 3         104   Smartphone  Electronics  14999     Klokata
# 4         105        Books        Study    145       Delhi
# 5         106          Oil      Grocery    110     Chennai
# 6         107       Laptop  Electronics  79999   Bengalore

# %%
# Reading csv external file using pandas
customer_df=pd.read_csv('datasets/customer.csv')
#printing product_df data frame
customer_df
# Out:
#    ID     Name  Age  Product_ID Purchased_Product       City
# 0   1   Olivia   20         101             Watch     Mumbai
# 1   2   Aditya   25           0                Na      Delhi
# 2   3     Cory   15         106               Oil  Bangalore
# 3   4  Isabell   10           0               NaN    Chennai
# 4   5  Dominic   30         103             Shoes    Chennai
# 5   6    Tyler   65         104        Smartphone      Delhi
# 6   7   Samuel   35           0               NaN    Kolkata
# 7   8   Daniel   18           0               NaN      Delhi
# 8   9   Jeremy   23         107            Laptop     Mumbai

# %%
#Inner merge
pd.merge(product_df,customer_df,how='inner', on='Product_ID')
# Out:
#    Product_ID Product_Name     Category  Price Seller_City  ID     Name  Age  \
# 0         101        Watch      Fashion    299       Delhi   1   Olivia   20
# 1         103        Shoes      Fashion   2999     Chennai   5  Dominic   30
# 2         104   Smartphone  Electronics  14999     Klokata   6    Tyler   65
# 3         106          Oil      Grocery    110     Chennai   3     Cory   15
# 4         107       Laptop  Electronics  79999   Bengalore   9   Jeremy   23
#
#   Purchased_Product       City
# 0             Watch     Mumbai
# 1             Shoes    Chennai
# 2        Smartphone      Delhi
# 3               Oil  Bangalore
# 4            Laptop     Mumbai

# %%
pd.merge(product_df,customer_df,how='inner',left_on='Product_Name',right_on='Purchased_Product')
# Out:
#    Product_ID_x Product_Name     Category  Price Seller_City  ID     Name  \
# 0           101        Watch      Fashion    299       Delhi   1   Olivia
# 1           103        Shoes      Fashion   2999     Chennai   5  Dominic
# 2           104   Smartphone  Electronics  14999     Klokata   6    Tyler
# 3           106          Oil      Grocery    110     Chennai   3     Cory
# 4           107       Laptop  Electronics  79999   Bengalore   9   Jeremy
#
#    Age  Product_ID_y Purchased_Product       City
# 0   20           101             Watch     Mumbai
# 1   30           103             Shoes    Chennai
# 2   65           104        Smartphone      Delhi
# 3   15           106               Oil  Bangalore
# 4   23           107            Laptop     Mumbai

# %%
pd.merge(product_df,customer_df,how='inner',
         left_on=['Product_ID','Seller_City'],
         right_on=['Product_ID','City'])
# Out:
#    Product_ID Product_Name Category  Price Seller_City  ID     Name  Age  \
# 0         103        Shoes  Fashion   2999     Chennai   5  Dominic   30
#
#   Purchased_Product     City
# 0             Shoes  Chennai

# %% [markdown]
# # Full merge

# %%
pd.merge(product_df,customer_df,on='Product_ID',how='outer')
# Out:
#     Product_ID Product_Name     Category    Price Seller_City   ID     Name  \
# 0          101        Watch      Fashion    299.0       Delhi  1.0   Olivia
# 1          102          Bag      Fashion   1350.0      Mumbai  NaN      NaN
# 2          103        Shoes      Fashion   2999.0     Chennai  5.0  Dominic
# 3          104   Smartphone  Electronics  14999.0     Klokata  6.0    Tyler
# 4          105        Books        Study    145.0       Delhi  NaN      NaN
# 5          106          Oil      Grocery    110.0     Chennai  3.0     Cory
# 6          107       Laptop  Electronics  79999.0   Bengalore  9.0   Jeremy
# 7            0          NaN          NaN      NaN         NaN  2.0   Aditya
# 8            0          NaN          NaN      NaN         NaN  4.0  Isabell
# 9            0          NaN          NaN      NaN         NaN  7.0   Samuel
# 10           0          NaN          NaN      NaN         NaN  8.0   Daniel
#
#      Age Purchased_Product       City
# ...

# %%
pd.merge(product_df,customer_df,on='Product_ID',how='outer',indicator=True)
# Out:
#     Product_ID Product_Name     Category    Price Seller_City   ID     Name  \
# 0          101        Watch      Fashion    299.0       Delhi  1.0   Olivia
# 1          102          Bag      Fashion   1350.0      Mumbai  NaN      NaN
# 2          103        Shoes      Fashion   2999.0     Chennai  5.0  Dominic
# 3          104   Smartphone  Electronics  14999.0     Klokata  6.0    Tyler
# 4          105        Books        Study    145.0       Delhi  NaN      NaN
# 5          106          Oil      Grocery    110.0     Chennai  3.0     Cory
# 6          107       Laptop  Electronics  79999.0   Bengalore  9.0   Jeremy
# 7            0          NaN          NaN      NaN         NaN  2.0   Aditya
# 8            0          NaN          NaN      NaN         NaN  4.0  Isabell
# 9            0          NaN          NaN      NaN         NaN  7.0   Samuel
# 10           0          NaN          NaN      NaN         NaN  8.0   Daniel
#
#      Age Purchased_Product       City      _merge
# ...

# %% [markdown]
# # Left Merge

# %%
#Left Merge
pd.merge(product_df,customer_df,on='Product_ID',how='left')
# Out:
#    Product_ID Product_Name     Category  Price Seller_City   ID     Name  \
# 0         101        Watch      Fashion    299       Delhi  1.0   Olivia
# 1         102          Bag      Fashion   1350      Mumbai  NaN      NaN
# 2         103        Shoes      Fashion   2999     Chennai  5.0  Dominic
# 3         104   Smartphone  Electronics  14999     Klokata  6.0    Tyler
# 4         105        Books        Study    145       Delhi  NaN      NaN
# 5         106          Oil      Grocery    110     Chennai  3.0     Cory
# 6         107       Laptop  Electronics  79999   Bengalore  9.0   Jeremy
#
#     Age Purchased_Product       City
# 0  20.0             Watch     Mumbai
# 1   NaN               NaN        NaN
# 2  30.0             Shoes    Chennai
# 3  65.0        Smartphone      Delhi
# 4   NaN               NaN        NaN
# 5  15.0               Oil  Bangalore
# 6  23.0            Laptop     Mumbai

# %% [markdown]
# # Right Merge

# %%
pd.merge(product_df,customer_df,on='Product_ID',how='right',sort=True, indicator=True)
# Out:
#    Product_ID Product_Name     Category    Price Seller_City  ID     Name  \
# 0           0          NaN          NaN      NaN         NaN   2   Aditya
# 1           0          NaN          NaN      NaN         NaN   4  Isabell
# 2           0          NaN          NaN      NaN         NaN   7   Samuel
# 3           0          NaN          NaN      NaN         NaN   8   Daniel
# 4         101        Watch      Fashion    299.0       Delhi   1   Olivia
# 5         103        Shoes      Fashion   2999.0     Chennai   5  Dominic
# 6         104   Smartphone  Electronics  14999.0     Klokata   6    Tyler
# 7         106          Oil      Grocery    110.0     Chennai   3     Cory
# 8         107       Laptop  Electronics  79999.0   Bengalore   9   Jeremy
#
#    Age Purchased_Product       City      _merge
# 0   25                Na      Delhi  right_only
# 1   10               NaN    Chennai  right_only
# 2   35               NaN    Kolkata  right_only
# ...

# %% [markdown]
# # Handling Redundancy/Duplicates in Merge

# %%
"""Reading product_details_with_duplicate_data.csv file 
which is having duplicates data"""

product_duplicate=pd.read_csv('datasets/product_details_with_duplicate_data.csv')
product_duplicate
# Out:
#    Product_ID Product_name     Category    Price Seller_City
# 0         101        Watch      Fashion    299.0       Delhi
# 1         102          Bag      Fashion   1350.5      Mumbai
# 2         103        Shoes      Fashion   2999.0     Chennai
# 3         104   Smartphone  Electronics  14999.0     Kolkata
# 4         105        Books        Study    145.0       Delhi
# 5         106          Oil      Grocery    110.0     Chennai
# 6         107       Laptop  Electronics  79999.0   Bengalore
# 7         103        Shoes      Fashion   2999.0     Chennai
# 8         107       Laptop  Electronics  79999.0   Bengalore

# %%
product_duplicate.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# 8     True
# dtype: bool

# %%
#drop duplicates in dataset before merge
pd.merge(product_duplicate.drop_duplicates(),customer_df,how='inner',on='Product_ID')
# Out:
#    Product_ID Product_name     Category    Price Seller_City  ID     Name  \
# 0         101        Watch      Fashion    299.0       Delhi   1   Olivia
# 1         103        Shoes      Fashion   2999.0     Chennai   5  Dominic
# 2         104   Smartphone  Electronics  14999.0     Kolkata   6    Tyler
# 3         106          Oil      Grocery    110.0     Chennai   3     Cory
# 4         107       Laptop  Electronics  79999.0   Bengalore   9   Jeremy
#
#    Age Purchased_Product       City
# 0   20             Watch     Mumbai
# 1   30             Shoes    Chennai
# 2   65        Smartphone      Delhi
# 3   15               Oil  Bangalore
# 4   23            Laptop     Mumbai

# %%
#use validator in merege
pd.merge(product_duplicate,customer_df,how='inner',on='Product_ID', validate='many_to_many')
# Out:
#    Product_ID Product_name     Category    Price Seller_City  ID     Name  \
# 0         101        Watch      Fashion    299.0       Delhi   1   Olivia
# 1         103        Shoes      Fashion   2999.0     Chennai   5  Dominic
# 2         103        Shoes      Fashion   2999.0     Chennai   5  Dominic
# 3         104   Smartphone  Electronics  14999.0     Kolkata   6    Tyler
# 4         106          Oil      Grocery    110.0     Chennai   3     Cory
# 5         107       Laptop  Electronics  79999.0   Bengalore   9   Jeremy
# 6         107       Laptop  Electronics  79999.0   Bengalore   9   Jeremy
#
#    Age Purchased_Product       City
# 0   20             Watch     Mumbai
# 1   30             Shoes    Chennai
# 2   30             Shoes    Chennai
# 3   65        Smartphone      Delhi
# 4   15               Oil  Bangalore
# 5   23            Laptop     Mumbai
# 6   23            Laptop     Mumbai

# %% [markdown]
# # Changing the Index and Column Headers

# %%
# Creating df1 to demostarte Indexing and Chnage Column headers
df1 = pd.DataFrame({"Day":[1,2,3,4],"Visitors":[200,100,230,300],"Bounce_Rate":[20,45,60,10]})
df1
# Out:
#    Day  Visitors  Bounce_Rate
# 0    1       200           20
# 1    2       100           45
# 2    3       230           60
# 3    4       300           10

# %%
df1.set_index('Day', inplace=True)

# %%
df1.rename(columns={'Day':'Id', 'Visitors':'Visitor'})
# Out:
#      Visitor  Bounce_Rate
# Day
# 1        200           20
# 2        100           45
# 3        230           60
# 4        300           10

# %% [markdown]
# # Before Getting Started Create three Data Frames for learning Concatenation

# %%
#Creating dataframe df1
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']},
                   index=[0, 1, 2, 3])
#Dsipalying df1
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
#creating df2
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']},
                   index=[4, 5, 6, 7])
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
# creating df3
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                    'B': ['B8', 'B9', 'B10', 'B11'],
                    'C': ['C8', 'C9', 'C10', 'C11'],
                    'D': ['D8', 'D9', 'D10', 'D11']},
                   index=[8, 9, 10, 11])
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# # Putting dataframes df1,df2, and df3 into a list

# %%
#Putting dataframes df1,df2, and df3 into a list
frames = [df1, df2, df3]

# %%
frames
# Out:
# [    A   B   C   D
#  0  A0  B0  C0  D0
#  1  A1  B1  C1  D1
#  2  A2  B2  C2  D2
#  3  A3  B3  C3  D3,
#      A   B   C   D
#  4  A4  B4  C4  D4
#  5  A5  B5  C5  D5
#  6  A6  B6  C6  D6
#  7  A7  B7  C7  D7,
#        A    B    C    D
#  8    A8   B8   C8   D8
#  9    A9   B9   C9   D9
#  10  A10  B10  C10  D10
#  11  A11  B11  C11  D11]

# %% [markdown]
# # Concatenating dataframes df1,df2 and df3 using concat() function

# %%
#Concatenating dataframes df1,df2 and df3
result = pd.concat([df1,df2,df3])
#Printing result dataframe after concatenation
result
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
"""To associate specific keys with each of the pieces of the chopped up DataFrame. 
We can do this using the keys argument"""
result = pd.concat(frames, keys=['x', 'y', 'z'])
result
# Out:
#         A    B    C    D
# x 0    A0   B0   C0   D0
#   1    A1   B1   C1   D1
#   2    A2   B2   C2   D2
#   3    A3   B3   C3   D3
# y 4    A4   B4   C4   D4
#   5    A5   B5   C5   D5
#   6    A6   B6   C6   D6
#   7    A7   B7   C7   D7
# z 8    A8   B8   C8   D8
#   9    A9   B9   C9   D9
#   10  A10  B10  C10  D10
#   11  A11  B11  C11  D11

# %% [markdown]
# # Python Pandas Indexing, Slicing and Subsetting DataFrames<hr>
